# %% [markdown]
# # Cash Print Badge Mode Test

# %%
import cash
import pandas as pd
import numpy as np
print(f"Cash version: {cash.__version__}")

# %%
# %load_ext cash
# %cash_on
# %cash_badge print

# %%
np.random.seed(42)
n = 100_000
df = pd.DataFrame({
    'date': pd.date_range('2020-01-01', periods=n, freq='h'),
    'price': np.cumsum(np.random.randn(n)) + 100,
    'volume': np.random.randint(100, 10000, n),
    'category': np.random.choice(['A', 'B', 'C', 'D'], n)
})
print(f"Created DataFrame: {df.shape}")
