# %%
# Test cell 1: Simple calculation
x = 10
y = 20
result = x + y
print(f"Result: {result}")

# %%
# %cash_on
# %cash_debug on

# %%
# Test cell 2: Import pandas
import pandas as pd

df = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50]
})

df

# %%
# Test cell 3: Simple plot
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
plt.plot(df['A'], df['B'], marker='o')
plt.title('Simple Plot')
plt.xlabel('A')
plt.ylabel('B')
plt.grid(True)
plt.show()
